# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ### Import data & Data Exploration

# %%
data = pd.read_csv('./data/supermarket_sales.csv')
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 0     1/5/2019  13:08      Ewallet  522.83                 4.761905
# 1     3/8/2019  10:29         Cash   76.40                 4.761905
# 2     3/3/2019  13:23  Credit card  324.31                 4.761905
# 3    1/27/2019  20:33      Ewallet  465.76                 4.761905
# 4     2/8/2019  10:37      Ewallet  604.17                 4.761905
# ..         ...    ...          ...     ...                      ...
# 995  1/29/2019  13:46      Ewallet   40.35                 4.761905
# 996   3/2/2019  17:16      Ewallet  973.80                 4.761905
# 997   2/9/2019  13:22         Cash   31.84                 4.761905
# 998  2/22/2019  15:33         Cash   65.82                 4.761905
# 999  2/18/2019  13:28         Cash  618.38                 4.761905
#
#      gross income  Rating
# 0         26.1415     9.1
# 1          3.8200     9.6
# 2         16.2155     7.4
# 3         23.2880     8.4
# 4         30.2085     5.3
# ..            ...     ...
# 995        2.0175     6.2
# 996       48.6900     4.4
# 997        1.5920     7.7
# 998        3.2910     4.1
# 999       30.9190     6.6
#
# [1000 rows x 17 columns]

# %%
styled_data = data.head(10).style.set_properties(**{'background-color': '#228B22', 'color':'Black', 'border':'black'})
styled_data.set_table_styles([{"selector": "th", "props": [("color", 'white'), ("background-color", "Black")]}
                              ])
# Out:
# <style type="text/css">
# #T_75012 th {
#   color: white;
#   background-color: Black;
# }
# #T_75012_row0_col0, #T_75012_row0_col1, #T_75012_row0_col2, #T_75012_row0_col3, #T_75012_row0_col4, #T_75012_row0_col5, #T_75012_row0_col6, #T_75012_row0_col7, #T_75012_row0_col8, #T_75012_row0_col9, #T_75012_row0_col10, #T_75012_row0_col11, #T_75012_row0_col12, #T_75012_row0_col13, #T_75012_row0_col14, #T_75012_row0_col15, #T_75012_row0_col16, #T_75012_row1_col0, #T_75012_row1_col1, #T_75012_row1_col2, #T_75012_row1_col3, #T_75012_row1_col4, #T_75012_row1_col5, #T_75012_row1_col6, #T_75012_row1_col7, #T_75012_row1_col8, #T_75012_row1_col9, #T_75012_row1_col10, #T_75012_row1_col11, #T_75012_row1_col12, #T_75012_row1_col13, #T_75012_row1_col14, #T_75012_row1_col15, #T_75012_row1_col16, #T_75012_row2_col0, #T_75012_row2_col1, #T_75012_row2_col2, #T_75012_row2_col3, #T_75012_row2_col4, #T_75012_row2_col5, #T_75012_row2_col6, #T_75012_row2_col7, #T_75012_row2_col8, #T_75012_row2_col9, #T_75012_row2_col10, #T_75012_row2_col11, #T_75012_row2_col12, #T_75012_row2_col13, #T_75012_row2_col14, #T_75012_row2_col15, #T_75012_row2_col16, #T_75012_row3_col0, #T_75012_row3_col1, #T_75012_row3_col2, #T_75012_row3_col3, #T_75012_row3_col4, #T_75012_row3_col5, #T_75012_row3_col6, #T_75012_row3_col7, #T_75012_row3_col8, #T_75012_row3_col9, #T_75012_row3_col10, #T_75012_row3_col11, #T_75012_row3_col12, #T_75012_row3_col13, #T_75012_row3_col14, #T_75012_row3_col15, #T_75012_row3_col16, #T_75012_row4_col0, #T_75012_row4_col1, #T_75012_row4_col2, #T_75012_row4_col3, #T_75012_row4_col4, #T_75012_row4_col5, #T_75012_row4_col6, #T_75012_row4_col7, #T_75012_row4_col8, #T_75012_row4_col9, #T_75012_row4_col10, #T_75012_row4_col11, #T_75012_row4_col12, #T_75012_row4_col13, #T_75012_row4_col14, #T_75012_row4_col15, #T_75012_row4_col16, #T_75012_row5_col0, #T_75012_row5_col1, #T_75012_row5_col2, #T_75012_row5_col3, #T_75012_row5_col4, #T_75012_row5_col5, #T_75012_row5_col6, #T_75012_row5_col7, #T_75012_row5_col8, #T_75012_row5_col9, #T_75012_row5_col10, #T_75012_row5_col11, #T_75012_row5_col12, #T_75012_row5_col13, #T_75012_row5_col14, #T_75012_row5_col15, #T_75012_row5_col16, #T_75012_row6_col0, #T_75012_row6_col1, #T_75012_row6_col2, #T_75012_row6_col3, #T_75012_row6_col4, #T_75012_row6_col5, #T_75012_row6_col6, #T_75012_row6_col7, #T_75012_row6_col8, #T_75012_row6_col9, #T_75012_row6_col10, #T_75012_row6_col11, #T_75012_row6_col12, #T_75012_row6_col13, #T_75012_row6_col14, #T_75012_row6_col15, #T_75012_row6_col16, #T_75012_row7_col0, #T_75012_row7_col1, #T_75012_row7_col2, #T_75012_row7_col3, #T_75012_row7_col4, #T_75012_row7_col5, #T_75012_row7_col6, #T_75012_row7_col7, #T_75012_row7_col8, #T_75012_row7_col9, #T_75012_row7_col10, #T_75012_row7_col11, #T_75012_row7_col12, #T_75012_row7_col13, #T_75012_row7_col14, #T_75012_row7_col15, #T_75012_row7_col16, #T_75012_row8_col0, #T_75012_row8_col1, #T_75012_row8_col2, #T_75012_row8_col3, #T_75012_row8_col4, #T_75012_row8_col5, #T_75012_row8_col6, #T_75012_row8_col7, #T_75012_row8_col8, #T_75012_row8_col9, #T_75012_row8_col10, #T_75012_row8_col11, #T_75012_row8_col12, #T_75012_row8_col13, #T_75012_row8_col14, #T_75012_row8_col15, #T_75012_row8_col16, #T_75012_row9_col0, #T_75012_row9_col1, #T_75012_row9_col2, #T_75012_row9_col3, #T_75012_row9_col4, #T_75012_row9_col5, #T_75012_row9_col6, #T_75012_row9_col7, #T_75012_row9_col8, #T_75012_row9_col9, #T_75012_row9_col10, #T_75012_row9_col11, #T_75012_row9_col12, #T_75012_row9_col13, #T_75012_row9_col14, #T_75012_row9_col15, #T_75012_row9_col16 {
#   background-color: #228B22;
#   color: Black;
#   border: black;
# }
# </style>
# <table id="T_75012">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75012_level0_col0" class="col_heading level0 col0" >Invoice ID</th>
#       <th id="T_75012_level0_col1" class="col_heading level0 col1" >Branch</th>
#       <th id="T_75012_level0_col2" class="col_heading level0 col2" >City</th>
#       <th id="T_75012_level0_col3" class="col_heading level0 col3" >Customer type</th>
#       <th id="T_75012_level0_col4" class="col_heading level0 col4" >Gender</th>
#       <th id="T_75012_level0_col5" class="col_heading level0 col5" >Product line</th>
#       <th id="T_75012_level0_col6" class="col_heading level0 col6" >Unit price</th>
#       <th id="T_75012_level0_col7" class="col_heading level0 col7" >Quantity</th>
#       <th id="T_75012_level0_col8" class="col_heading level0 col8" >Tax 5%</th>
#       <th id="T_75012_level0_col9" class="col_heading level0 col9" >Total</th>
#       <th id="T_75012_level0_col10" class="col_heading level0 col10" >Date</th>
#       <th id="T_75012_level0_col11" class="col_heading level0 col11" >Time</th>
#       <th id="T_75012_level0_col12" class="col_heading level0 col12" >Payment</th>
#       <th id="T_75012_level0_col13" class="col_heading level0 col13" >cogs</th>
#       <th id="T_75012_level0_col14" class="col_heading level0 col14" >gross margin percentage</th>
#       <th id="T_75012_level0_col15" class="col_heading level0 col15" >gross income</th>
#       <th id="T_75012_level0_col16" class="col_heading level0 col16" >Rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75012_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75012_row0_col0" class="data row0 col0" >750-67-8428</td>
#       <td id="T_75012_row0_col1" class="data row0 col1" >A</td>
#       <td id="T_75012_row0_col2" class="data row0 col2" >Yangon</td>
#       <td id="T_75012_row0_col3" class="data row0 col3" >Member</td>
#       <td id="T_75012_row0_col4" class="data row0 col4" >Female</td>
#       <td id="T_75012_row0_col5" class="data row0 col5" >Health and beauty</td>
#       <td id="T_75012_row0_col6" class="data row0 col6" >74.690000</td>
#       <td id="T_75012_row0_col7" class="data row0 col7" >7</td>
#       <td id="T_75012_row0_col8" class="data row0 col8" >26.141500</td>
#       <td id="T_75012_row0_col9" class="data row0 col9" >548.971500</td>
#       <td id="T_75012_row0_col10" class="data row0 col10" >1/5/2019</td>
#       <td id="T_75012_row0_col11" class="data row0 col11" >13:08</td>
#       <td id="T_75012_row0_col12" class="data row0 col12" >Ewallet</td>
#       <td id="T_75012_row0_col13" class="data row0 col13" >522.830000</td>
#       <td id="T_75012_row0_col14" class="data row0 col14" >4.761905</td>
#       <td id="T_75012_row0_col15" class="data row0 col15" >26.141500</td>
#       <td id="T_75012_row0_col16" class="data row0 col16" >9.100000</td>
#     </tr>
#     <tr>
#       <th id="T_75012_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_75012_row1_col0" class="data row1 col0" >226-31-3081</td>
#       <td id="T_75012_row1_col1" class="data row1 col1" >C</td>
#       <td id="T_75012_row1_col2" class="data row1 col2" >Naypyitaw</td>
#       <td id="T_75012_row1_col3" class="data row1 col3" >Normal</td>
#       <td id="T_75012_row1_col4" class="data row1 col4" >Female</td>
#       <td id="T_75012_row1_col5" class="data row1 col5" >Electronic accessories</td>
#       <td id="T_75012_row1_col6" class="data row1 col6" >15.280000</td>
#       <td id="T_75012_row1_col7" class="data row1 col7" >5</td>
#       <td id="T_75012_row1_col8" class="data row1 col8" >3.820000</td>
#       <td id="T_75012_row1_col9" class="data row1 col9" >80.220000</td>
#       <td id="T_75012_row1_col10" class="data row1 col10" >3/8/2019</td>
#       <td id="T_75012_row1_col11" class="data row1 col11" >10:29</td>
#       <td id="T_75012_row1_col12" class="data row1 col12" >Cash</td>
#       <td id="T_75012_row1_col13" class="data row1 col13" >76.400000</td>
#       <td id="T_75012_row1_col14" class="data row1 col14" >4.761905</td>
#       <td id="T_75012_row1_col15" class="data row1 col15" >3.820000</td>
#       <td id="T_75012_row1_col16" class="data row1 col16" >9.600000</td>
#     </tr>
#     <tr>
#       <th id="T_75012_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_75012_row2_col0" class="data row2 col0" >631-41-3108</td>
#       <td id="T_75012_row2_col1" class="data row2 col1" >A</td>

# %%
data.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %%
data.isna().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
desc = pd.DataFrame(index = list(data))
desc['type'] = data.dtypes
desc['count'] = data.count()
desc['nunique'] = data.nunique()
desc['%unique'] = desc['nunique'] /len(data) * 100
desc['null'] = data.isnull().sum()
desc['%null'] = desc['null'] / len(data) * 100
desc = pd.concat([desc,data.describe().T.drop('count',axis=1)],axis=1)
desc.sort_values(by=['type','null']).style.background_gradient(cmap='YlOrBr')\
    .bar(subset=['mean'],color='green')\
    .bar(subset=['max'],color='red')\
    .bar(subset=['min'], color='pink')
# Out:
# <style type="text/css">
# #T_956e9_row0_col1, #T_956e9_row0_col4, #T_956e9_row0_col5, #T_956e9_row0_col9, #T_956e9_row0_col10, #T_956e9_row1_col1, #T_956e9_row1_col4, #T_956e9_row1_col5, #T_956e9_row2_col1, #T_956e9_row2_col4, #T_956e9_row2_col5, #T_956e9_row3_col1, #T_956e9_row3_col4, #T_956e9_row3_col5, #T_956e9_row4_col1, #T_956e9_row4_col4, #T_956e9_row4_col5, #T_956e9_row5_col1, #T_956e9_row5_col2, #T_956e9_row5_col3, #T_956e9_row5_col4, #T_956e9_row5_col5, #T_956e9_row5_col7, #T_956e9_row5_col10, #T_956e9_row5_col11, #T_956e9_row6_col1, #T_956e9_row6_col4, #T_956e9_row6_col5, #T_956e9_row7_col1, #T_956e9_row7_col4, #T_956e9_row7_col5, #T_956e9_row8_col1, #T_956e9_row8_col4, #T_956e9_row8_col5, #T_956e9_row9_col1, #T_956e9_row9_col2, #T_956e9_row9_col3, #T_956e9_row9_col4, #T_956e9_row9_col5, #T_956e9_row10_col1, #T_956e9_row10_col2, #T_956e9_row10_col3, #T_956e9_row10_col4, #T_956e9_row10_col5, #T_956e9_row11_col1, #T_956e9_row11_col2, #T_956e9_row11_col3, #T_956e9_row11_col4, #T_956e9_row11_col5, #T_956e9_row12_col1, #T_956e9_row12_col2, #T_956e9_row12_col3, #T_956e9_row12_col4, #T_956e9_row12_col5, #T_956e9_row13_col1, #T_956e9_row13_col4, #T_956e9_row13_col5, #T_956e9_row14_col1, #T_956e9_row14_col4, #T_956e9_row14_col5, #T_956e9_row15_col1, #T_956e9_row15_col4, #T_956e9_row15_col5, #T_956e9_row16_col1, #T_956e9_row16_col2, #T_956e9_row16_col3, #T_956e9_row16_col4, #T_956e9_row16_col5 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_956e9_row0_col2, #T_956e9_row0_col3, #T_956e9_row7_col10, #T_956e9_row7_col11 {
#   background-color: #fffee2;
#   color: #000000;
# }
# #T_956e9_row0_col6 {
#   background-color: #ffffe5;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, green 1.7%, transparent 1.7%);
# }
# #T_956e9_row0_col7, #T_956e9_row5_col9 {
#   background-color: #fffee1;
#   color: #000000;
# }
# #T_956e9_row0_col8 {
#   background-color: #fffcd6;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, pink 9.4%, transparent 9.4%);
# }
# #T_956e9_row0_col11, #T_956e9_row7_col7, #T_956e9_row13_col2, #T_956e9_row13_col3 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_956e9_row0_col12, #T_956e9_row7_col12 {
#   background-color: #ffffe4;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, red 1.0%, transparent 1.0%);
# }
# #T_956e9_row1_col2, #T_956e9_row1_col3 {
#   background-color: #7c2c05;
#   color: #f1f1f1;
# }
# #T_956e9_row1_col6 {
#   background-color: #fff2b1;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, green 17.2%, transparent 17.2%);
# }
# #T_956e9_row1_col7 {
#   background-color: #fff8c2;
#   color: #000000;
# }
# #T_956e9_row1_col8 {
#   background-color: #7e2c05;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, pink 94.4%, transparent 94.4%);
# }
# #T_956e9_row1_col9 {
#   background-color: #fee493;
#   color: #000000;
# }
# #T_956e9_row1_col10 {
#   background-color: #feeba2;
#   color: #000000;
# }
# #T_956e9_row1_col11 {
#   background-color: #fff2b1;
#   color: #000000;
# }
# #T_956e9_row1_col12 {
#   background-color: #fff9c7;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, red 9.6%, transparent 9.6%);
# }
# #T_956e9_row2_col2, #T_956e9_row2_col3, #T_956e9_row3_col2, #T_956e9_row3_col3, #T_956e9_row4_col2, #T_956e9_row4_col3, #T_956e9_row6_col2, #T_956e9_row6_col3 {
#   background-color: #692606;
#   color: #f1f1f1;
# }
# #T_956e9_row2_col6, #T_956e9_row6_col6 {
#   background-color: #fffddb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, green 4.8%, transparent 4.8%);
# }
# #T_956e9_row2_col7, #T_956e9_row6_col7 {
#   background-color: #fffcd6;
#   color: #000000;
# }
# #T_956e9_row2_col8, #T_956e9_row6_col8 {
#   background-color: #ffffe5;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, pink 4.8%, transparent 4.8%);
# }
# #T_956e9_row2_col9, #T_956e9_row6_col9 {
#   background-color: #fffddd;
#   color: #000000;
# }
# #T_956e9_row2_col10, #T_956e9_row6_col10 {
#   background-color: #fffddc;
#   color: #000000;
# }
# #T_956e9_row2_col11, #T_956e9_row6_col11 {
#   background-color: #fffdd9;
#   color: #000000;
# }
# #T_956e9_row2_col12, #T_956e9_row6_col12 {
#   background-color: #fffcd7;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, red 4.8%, transparent 4.8%);
# }
# #T_956e9_row3_col6 {
#   background-color: #662506;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, green 100.0%, transparent 100.0%);
# }
# #T_956e9_row3_col7, #T_956e9_row3_col9, #T_956e9_row3_col10, #T_956e9_row3_col11, #T_956e9_row8_col2, #T_956e9_row8_col3 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_956e9_row3_col8 {
#   background-color: #662506;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, pink 100.0%, transparent 100.0%);
# }
# #T_956e9_row3_col12 {
#   background-color: #662506;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, red 100.0%, transparent 100.0%);
# }
# #T_956e9_row4_col6 {
#   background-color: #792b05;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, green 95.2%, transparent 95.2%);
# }
# #T_956e9_row4_col7, #T_956e9_row4_col9, #T_956e9_row4_col10, #T_956e9_row4_col11 {
#   background-color: #792b05;
#   color: #f1f1f1;
# }
# #T_956e9_row4_col8 {
#   background-color: #792b05;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, pink 95.2%, transparent 95.2%);
# }
# #T_956e9_row4_col12 {
#   background-color: #792b05;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, red 95.2%, transparent 95.2%);
# }
# #T_956e9_row5_col6 {
#   background-color: #ffffe5;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, green 1.5%, transparent 1.5%);
# }
# #T_956e9_row5_col8 {
#   background-color: #feb541;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, pink 44.6%, transparent 44.6%);
# }
# #T_956e9_row5_col12 {
#   background-color: #ffffe5;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, red 0.5%, transparent 0.5%);
# }
# #T_956e9_row7_col2, #T_956e9_row7_col3 {
#   background-color: #fffbd2;
#   color: #000000;
# }
# #T_956e9_row7_col6 {
#   background-color: #ffffe4;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, green 2.2%, transparent 2.2%);
# }
# #T_956e9_row7_col8 {
#   background-color: #fecc61;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, pink 37.5%, transparent 37.5%);
# }
# #T_956e9_row7_col9 {
#   background-color: #fffedf;
#   color: #000000;
# }
# #T_956e9_row8_col6, #T_956e9_row8_col8, #T_956e9_row8_col12, #T_956e9_row9_col6, #T_956e9_row9_col8, #T_956e9_row9_col12, #T_956e9_row10_col6, #T_956e9_row10_col8, #T_956e9_row10_col12, #T_956e9_row11_col6, #T_956e9_row11_col8, #T_956e9_row11_col12, #T_956e9_row12_col6, #T_956e9_row12_col8, #T_956e9_row12_col12, #T_956e9_row13_col6, #T_956e9_row13_col8, #T_956e9_row13_col12, #T_956e9_row14_col6, #T_956e9_row14_col8, #T_956e9_row14_col12, #T_956e9_row15_col6, #T_956e9_row15_col8, #T_956e9_row15_col12, #T_956e9_row16_col6, #T_956e9_row16_col8, #T_956e9_row16_col12 {
#   background-color: #000000;
#   color: #f1f1f1;
#   width: 10em;
# }
# #T_956e9_row8_col7, #T_956e9_row8_col9, #T_956e9_row8_col10, #T_956e9_row8_col11, #T_956e9_row9_col7, #T_956e9_row9_col9, #T_956e9_row9_col10, #T_956e9_row9_col11, #T_956e9_row10_col7, #T_956e9_row10_col9, #T_956e9_row10_col10, #T_956e9_row10_col11, #T_956e9_row11_col7, #T_956e9_row11_col9, #T_956e9_row11_col10, #T_956e9_row11_col11, #T_956e9_row12_col7, #T_956e9_row12_col9, #T_956e9_row12_col10, #T_956e9_row12_col11, #T_956e9_row13_col7, #T_956e9_row13_col9, #T_956e9_row13_col10, #T_956e9_row13_col11, #T_956e9_row14_col7, #T_956e9_row14_col9, #T_956e9_row14_col10, #T_956e9_row14_col11, #T_956e9_row15_col7, #T_956e9_row15_col9, #T_956e9_row15_col10, #T_956e9_row15_col11, #T_956e9_row16_col7, #T_956e9_row16_col9, #T_956e9_row16_col10, #T_956e9_row16_col11 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_956e9_row14_col2, #T_956e9_row14_col3 {
#   background-color: #fff9c9;
#   color: #000000;
# }
# #T_956e9_row15_col2, #T_956e9_row15_col3 {
#   background-color: #fd9728;

# %%
for col in data.columns:
  if col not in ('Invoice ID', 'Date', 'Time') and data[col].dtype =='object':
    print(f'{col} : {data[col].unique()}')
# Out:
# Branch : ['A' 'C' 'B']
# City : ['Yangon' 'Naypyitaw' 'Mandalay']
# Customer type : ['Member' 'Normal']
# Gender : ['Female' 'Male']
# Product line : ['Health and beauty' 'Electronic accessories' 'Home and lifestyle'
#  'Sports and travel' 'Food and beverages' 'Fashion accessories']
# Payment : ['Ewallet' 'Cash' 'Credit card']

# %% [markdown]
# ### Data Cleaning

# %%
data.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3

# %%
data.drop('Invoice ID', axis=1, inplace=True)

# %%
data['Date'] = pd.to_datetime(data['Date'])
data['day_of_week'] = data['Date'].dt.day_name()
data['day'] = data['Date'].dt.day
data['hour'] = data['Time'].str.split(':').str[0].astype(int)
data['month'] = data['Date'].dt.month_name()
data['year'] = data['Date'].dt.year

# %%
data.drop('Date', axis=1, inplace=True)
data.drop('Time', axis=1, inplace=True)

# %% [markdown]
# ### EDA

# %%
num_cols = data.select_dtypes(include=np.number).columns
cat_cols = data.select_dtypes(exclude=np.number).columns

# %%
num_col = num_cols[~num_cols.isin(['year', 'gross margin percentage'])]
num_rows = int(np.ceil(len(num_cols) / 3))
fig, axes = plt.subplots(num_rows, 3, figsize=(15,5 * num_rows))
axes = axes.ravel()
for i, col in enumerate(num_col):
  ax = sns.histplot(data[col], ax=axes[i], kde=True, bins=20, color='#c44e52')
  if ax.lines and hasattr(ax.lines[0], 'set_color'):
    ax.lines[0].set_color('crimson')
  axes[i].set_xlabel(col) 
  axes[i].set_ylabel('Frequency')
  axes[i].set_title(f'hist plot of {col}')
if len(axes) > len(num_col):
  for i in range(len(num_col), len(axes)):
    if axes[i] in fig.axes:
      fig.delaxes(axes[i])
plt.tight_layout()
plt.show()

# %%
cat_rows = int(np.ceil(len(cat_cols) / 3))
fig, axes = plt.subplots(cat_rows, 3, figsize=(15, 5 * cat_rows))
axes = axes.ravel()
for i, col in enumerate(cat_cols):
    plt.style.use("fivethirtyeight")
    count_prim = data[col].value_counts()
    count_prim = count_prim.sort_values(ascending=False)
    ax = sns.barplot(y=count_prim.index, x=count_prim.values, ax=axes[i], palette="Set3")
    ax.set_ylabel(col)
    ax.set_xlabel('Frequency')
    ax.set_title(f'Count Plot of {col}')
    for p in ax.patches:
      width = p.get_width()
      ax.text(width / 2,
            p.get_y() + p.get_height() / 2,
            '{:1.0f}'.format(width),
            ha="left",
            va="center")
plt.tight_layout()
plt.show()

# %%
correlation_matrix = data[num_col].corr(numeric_only=True)
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title(' Correlation Heatmap')
plt.show()

# %%
sns.scatterplot(data=data, y='Total',x='Rating', hue='Gender', style='Customer type')
plt.legend(loc='upper right', bbox_to_anchor=(1.5, 1))
plt.xlabel('Rating')
plt.ylabel('Total Sales')
plt.show()

# %%
plt.figure(figsize=(10,8))
salary_trend = data[['Total', 'day_of_week']].sort_values(by = 'day_of_week')
p = sns.lineplot(data, x='day', y='Total', markers='o', linestyle='--', color='Blue', markersize= 8)
plt.title('Total Trend Over The Time', fontsize=12, fontweight='bold')
p.set_facecolor('#f4f4f4')
plt.legend(['Total'], loc='best', fontsize=12)
p.grid(False)

plt.show()

# %%
data.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Payment', 'cogs',
#        'gross margin percentage', 'gross income', 'Rating', 'day_of_week',
#        'day', 'hour', 'month', 'year'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
p = sns.lineplot(data=data, x='Quantity', y='Total', hue='Branch', markers='0')
plt.title('Total Sales By Quantity')
plt.xlabel('Quantity')
plt.ylabel('Total Sales')
plt.legend(title='Branch')

plt.show()

# %%
mean_data = data.groupby('City')['Total'].mean()
plt.figure(figsize=(10,6))
ax = sns.barplot(x = mean_data.index, y=mean_data.values, palette='Set3')
plt.title('Total Sales By City', fontsize=12, fontweight='bold')
plt.xlabel('City')
plt.ylabel('Total Sales')
for container in ax.containers:
  ax.bar_label(container,
               padding=-50,
               fontsize=17,
               bbox={'boxstyle': 'circle', 'edgecolor': 'red', 'facecolor': 'yellow'},
               label_type="edge",
               fontweight='bold')
  
ax.set_facecolor('#f4f4f4')
ax.grid(False)
plt.show()

# %%
mean_data = data.groupby('Gender')['Total'].mean()

plt.figure(figsize=(10, 6))
ax = sns.barplot(x=mean_data.index, y=mean_data.values, palette='Set3')
plt.title('Total Sales By Gender', fontsize=12, fontweight='bold')
plt.xlabel('Gender')
plt.ylabel('Total Sales')

for container in ax.containers:
  ax.bar_label(container,
               padding=-50,
               fontsize=17,
               bbox={'boxstyle':'circle', 'edgecolor':'red', 'facecolor':'yellow'},
  label_type = "edge",
  fontweight = "bold")
  
ax.set_facecolor('#f4f4f4')  

ax.grid(False)

plt.show()

# %%
mean_data = data.groupby('Customer type')['Total'].mean()

plt.figure(figsize=(10,6))
p = sns.barplot(y=mean_data.values, x=mean_data.index, palette='Set3')
plt.title('Total Sales By Customer type', fontsize=12, fontweight='bold')
plt.xlabel('Customer type')
plt.ylabel('Total Sales')

for container in p.containers:
  plt.bar_label(container,
                padding=-50,
                fontsize=17,
                bbox={'boxstyle':'circle', 'edgecolor':'red','facecolor':'yellow'},
                label_type="edge",
                fontweight='bold',
               )
  
p.set_facecolor('#f4f4f4')
p.grid(False)

plt.show()

# %%
mean_data = data.groupby('Product line')['Total'].mean()

# Plot the average salary by company size
plt.figure(figsize=(10, 6))
p = sns.barplot(x=mean_data.index, y=mean_data.values, palette='Set3')
plt.title('Total Sales by Product line', fontsize=12, fontweight='bold')
plt.xlabel('Product line' )
plt.ylabel('Total Sales')
plt.xticks(rotation=90)


for container in p.containers:
    p.bar_label(container, fontweight = 'bold',
                padding = -12,
                fontsize=12,
                bbox = {'boxstyle': 'circle', 'facecolor': 'yellow', 'edgecolor': 'black'}

               )


plt.show()

# %% [markdown]
# ### Machine Learning

# %%
# Handling outliers

# %%
# Calculate the number of rows and columns for the subplots grid
num_rows = int(np.ceil(len(num_col) / 3))

fig, axes = plt.subplots(num_rows, 3, figsize=(15, 5 * num_rows))

axes = axes.flatten()

for i, col in enumerate(num_col):
  sns.boxplot(data[col], ax=axes[i] , color='Red')  # Plot on the corresponding subplot
  axes[i].set_title(col)  # Set title for each subplot

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %% [markdown]
# Encoding categorical data

# %%
data[cat_cols].columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line', 'Payment',
#        'day_of_week', 'month'],
#       dtype='object')

# %%
label_cols = ['Branch', 'City', 'Customer type', 'Gender', 'Product line', 'Payment', 'month', 'day_of_week']

le = LabelEncoder()
data[label_cols] = data[label_cols].apply(le.fit_transform)

# %%
correlation_matrix = data.corr(numeric_only=True)
correlation_price = correlation_matrix['Total'].sort_values(ascending=False).drop('Total')
plt.figure(figsize=(8,5))

sns.heatmap(correlation_price.to_frame(), annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

plt.title('Total')
plt.show()

# %% [markdown]
# # Models

# %%
X = data.drop('Total', axis=1)
y = data['Total']

# %%
anova_selector = SelectKBest(score_func=f_regression , k='all')
anova_selector.fit(X, y)
anova_scores = pd.Series(anova_selector.scores_, index=X.columns)
selected_features = anova_scores.sort_values(ascending=False).index[:9]
print("ANOVA Scores:")
print(anova_scores.sort_values(ascending=False))
print("\nSelected Features Based on Anova:\n", selected_features )
# Out:
# ANOVA Scores:
# cogs                       4.494592e+18
# gross income               1.123648e+18
# Tax 5%                     1.123648e+18
# Quantity                   9.890370e+02
# Unit price                 6.706394e+02
# Gender                     2.446492e+00
# Branch                     1.684297e+00
# Rating                     1.327104e+00
# Product line               9.988692e-01
# Customer type              3.862957e-01
# City                       1.638442e-01
# Payment                    1.543100e-01
# month                      4.512655e-02
# hour                       7.660046e-03
# day                        6.311457e-03
# day_of_week                4.039811e-03
# gross margin percentage    0.000000e+00
# year                       0.000000e+00
# dtype: float64
#
# Selected Features Based on Anova:
#  Index(['cogs', 'gross income', 'Tax 5%', 'Quantity', 'Unit price', 'Gender',
#        'Branch', 'Rating', 'Product line'],
#       dtype='object')

# %%
X_selected = data[selected_features]
y_selected = data['Total']

# %%
standard_scaler = StandardScaler()
X_selected = standard_scaler.fit_transform(X_selected)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_selected, y_selected, test_size=0.2, random_state=42)

# %%
model_KNN = KNeighborsRegressor()
model_KNN.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred_KNN = model_KNN.predict(X_test)

# %%
model_RF = RandomForestRegressor()
model_RF.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_RF = model_RF.predict(X_test)

# %%
model_SVR = SVR()
model_SVR.fit(X_train, y_train)
# Out:
# SVR()

# %%
y_pred_SVR = model_SVR.predict(X_test)

# %%
model_Gradient = GradientBoostingRegressor()
model_Gradient.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred_Gradient = model_Gradient.predict(X_test)

# %%
model_Hist = HistGradientBoostingRegressor()
model_Hist.fit(X_train, y_train)
# Out:
# HistGradientBoostingRegressor()

# %%
y_pred_Hist = model_Hist.predict(X_test)

# %%
def evaluate_model(y_test, y_pred):
    print("R2 Score:", r2_score(y_test, y_pred))
    print("MSE:", mean_squared_error(y_test, y_pred))
    print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))

# %%
for model in [model_KNN, model_RF, model_SVR, model_Gradient, model_Hist]:
        y_pred = model.predict(X_test)
        print(f"Model: {model.__class__.__name__}")
        print(f"R2 Score: {r2_score(y_test, y_pred)}")
        print(f"MSE: {mean_squared_error(y_test, y_pred)}")
        print(f"RMSE: {np.sqrt(mean_squared_error(y_test, y_pred))}")
        print(f"{'-'*50}")
# Out:
# Model: KNeighborsRegressor
# R2 Score: 0.9786834305931115
# MSE: 1386.8348241762005
# RMSE: 37.2402312583609
# --------------------------------------------------
# Model: RandomForestRegressor
# R2 Score: 0.9999787789482457
# MSE: 1.380620540612285
# RMSE: 1.174998102386674
# --------------------------------------------------
# Model: SVR
# R2 Score: 0.3384986116132024
# MSE: 43036.62302055309
# RMSE: 207.45270068271728
# --------------------------------------------------
# Model: GradientBoostingRegressor
# R2 Score: 0.999926089280847
# MSE: 4.8085579459185634
# RMSE: 2.1928424352694753
# --------------------------------------------------
# Model: HistGradientBoostingRegressor
# R2 Score: 0.99957728503357
# MSE: 27.50141568070766
# RMSE: 5.244179218972942
# --------------------------------------------------

# %%
results = []
for model in [model_KNN, model_RF, model_SVR, model_Gradient, model_Hist]:
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    results.append({
        'Model': model.__class__.__name__,
        'Train Score %': f"{r2_score(y_train, y_train_pred) * 100:.2f}",
        'Test Score %': f"{r2_score(y_test, y_test_pred) * 100:.2f}"
    })


results_df = pd.DataFrame(results)
styled_df = results_df.style.set_properties(**{'background-color': '#228B22' ,'color':'Black','border-color': 'black'})
styled_df.set_table_styles([
    {"selector": "th", "props": [("color", 'white'), ("background-color", "Black")]}
])
# Out:
# <style type="text/css">
# #T_364d0 th {
#   color: white;
#   background-color: Black;
# }
# #T_364d0_row0_col0, #T_364d0_row0_col1, #T_364d0_row0_col2, #T_364d0_row1_col0, #T_364d0_row1_col1, #T_364d0_row1_col2, #T_364d0_row2_col0, #T_364d0_row2_col1, #T_364d0_row2_col2, #T_364d0_row3_col0, #T_364d0_row3_col1, #T_364d0_row3_col2, #T_364d0_row4_col0, #T_364d0_row4_col1, #T_364d0_row4_col2 {
#   background-color: #228B22;
#   color: Black;
#   border-color: black;
# }
# </style>
# <table id="T_364d0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_364d0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_364d0_level0_col1" class="col_heading level0 col1" >Train Score %</th>
#       <th id="T_364d0_level0_col2" class="col_heading level0 col2" >Test Score %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_364d0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_364d0_row0_col0" class="data row0 col0" >KNeighborsRegressor</td>
#       <td id="T_364d0_row0_col1" class="data row0 col1" >98.45</td>
#       <td id="T_364d0_row0_col2" class="data row0 col2" >97.87</td>
#     </tr>
#     <tr>
#       <th id="T_364d0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_364d0_row1_col0" class="data row1 col0" >RandomForestRegressor</td>
#       <td id="T_364d0_row1_col1" class="data row1 col1" >100.00</td>
#       <td id="T_364d0_row1_col2" class="data row1 col2" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_364d0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_364d0_row2_col0" class="data row2 col0" >SVR</td>
#       <td id="T_364d0_row2_col1" class="data row2 col1" >37.99</td>
#       <td id="T_364d0_row2_col2" class="data row2 col2" >33.85</td>
#     </tr>
#     <tr>
#       <th id="T_364d0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_364d0_row3_col0" class="data row3 col0" >GradientBoostingRegressor</td>
#       <td id="T_364d0_row3_col1" class="data row3 col1" >100.00</td>
#       <td id="T_364d0_row3_col2" class="data row3 col2" >99.99</td>
#     </tr>
#     <tr>
#       <th id="T_364d0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_364d0_row4_col0" class="data row4 col0" >HistGradientBoostingRegressor</td>
#       <td id="T_364d0_row4_col1" class="data row4 col1" >99.97</td>
#       <td id="T_364d0_row4_col2" class="data row4 col2" >99.96</td>
#     </tr>
#   </tbody>
# </table>
